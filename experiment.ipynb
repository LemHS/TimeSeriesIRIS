# %%
from Model import bilstm, cnn_lstm, gru_lstm, vanilla_lstm
from train import train_model, evaluate_model, hypertune, plot_models

# %% [markdown]
# ## Vanilla LSTM

# %%
vilstm = vanilla_lstm.BuildVanillaLSTM

# %% [markdown]
# ### Single Shot

# %%
ss_vilstm_model, ss_vilstm_history, ss_vilstm_pred, ss_vilstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", vilstm, "SingleShot")
# Out:
# Trial 10 Complete [00h 00m 47s]
# val_root_mean_squared_error: 0.11595889180898666
#
# Best val_root_mean_squared_error So Far: 0.10698980838060379
# Total elapsed time: 00h 07m 23s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Dataframe all dates
#            rmse         mae      mape
# 0     46.480510   42.294027  0.025359
# 1     49.980517   47.867269  0.028525
# 2     46.800065   42.598063  0.025322
# 3     25.476446   20.333700  0.011985
# 4     17.622059   14.932454  0.008726
# ..          ...         ...       ...
# 584   92.596746   89.162598  0.032816
# 585  105.159043  103.828532  0.038202
# 586  128.205454  124.829671  0.046025
# 587  130.093050  127.000977  0.046901
# 588  126.892292  125.906982  0.046598
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    76.959053
# mae     72.167454
# mape     0.030241
# dtype: float64

# %% [markdown]
# ### Seq2Seq

# %%
seq2seq_vilstm_model, seq2seq_vilstm_history, seq2seq_vilstm_pred, seq2seq_vilstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", vilstm, "Seq2Seq")
# Out:
# Trial 10 Complete [00h 00m 40s]
# val_root_mean_squared_error: 0.2536165714263916
#
# Best val_root_mean_squared_error So Far: 0.09234193712472916
# Total elapsed time: 00h 11m 08s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Dataframe all dates
#            rmse         mae      mape
# 0     17.534891   15.945557  0.009358
# 1     21.319405   20.988403  0.012309
# 2     31.702814   27.413330  0.016090
# 3     42.118639   40.050090  0.023042
# 4     57.148296   51.483114  0.029336
# ..          ...         ...       ...
# 584  120.333865  117.345703  0.042743
# 585  127.072884  125.860270  0.045936
# 586  147.476995  144.414144  0.052862
# 587  141.828803  138.967773  0.051095
# 588  130.743997  129.692708  0.047931
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    75.349960
# mae     70.787662
# mape     0.029279
# dtype: float64

# %% [markdown]
# ### Autoregressive

# %%
ar_vilstm_model, ar_vilstm_history, ar_vilstm_pred, ar_vilstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", vilstm, "Autoregressive")
# Out:
# Trial 10 Complete [00h 00m 46s]
# val_root_mean_squared_error: 0.107648104429245
#
# Best val_root_mean_squared_error So Far: 0.10623268783092499
# Total elapsed time: 00h 06m 56s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Dataframe all dates
#            rmse         mae      mape
# 0     45.301154   39.208862  0.023486
# 1     48.123672   44.877238  0.026708
# 2     42.604435   39.518636  0.023426
# 3     20.754347   16.373372  0.009621
# 4     18.140693   16.505697  0.009643
# ..          ...         ...       ...
# 584   96.499664   95.480143  0.035088
# 585  110.401559  110.069092  0.040419
# 586  132.651941  130.786702  0.048139
# 587  134.413058  132.759277  0.048947
# 588  134.506361  131.711995  0.048607
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    77.659383
# mae     73.159362
# mape     0.030578
# dtype: float64

# %% [markdown]
# ## GRULSTM

# %%
grulstm = gru_lstm.BuildGRULSTM

# %% [markdown]
# ### SingleShot

# %%
ss_grulstm_model, ss_grulstm_history, ss_grulstm_pred, ss_grulstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", grulstm, "SingleShot")
# Out:
# Trial 10 Complete [00h 00m 47s]
# val_root_mean_squared_error: 0.11345651745796204
#
# Best val_root_mean_squared_error So Far: 0.09960579127073288
# Total elapsed time: 00h 07m 54s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Dataframe all dates
#            rmse         mae      mape
# 0     33.648712   24.308960  0.014435
# 1     36.380835   31.337565  0.018507
# 2     29.315838   25.121989  0.014762
# 3     19.312512   18.278931  0.010648
# 4     34.016398   33.422689  0.019339
# ..          ...         ...       ...
# 584  113.837119  112.776937  0.041178
# 585  125.769783  125.354248  0.045774
# 586  147.624675  145.923421  0.053412
# 587  146.128320  144.358805  0.052992
# 588  142.845776  140.547607  0.051708
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    80.434840
# mae     76.184299
# mape     0.031410
# dtype: float64

# %% [markdown]
# ### Seq2Seq

# %%
seq2seq_grulstm_model, seq2seq_grulstm_history, seq2seq_grulstm_pred, seq2seq_grulstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", grulstm, "Seq2Seq")
# Out:
# Trial 10 Complete [00h 01m 02s]
# val_root_mean_squared_error: 0.09723524749279022
#
# Best val_root_mean_squared_error So Far: 0.08042988181114197
# Total elapsed time: 00h 09m 00s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Dataframe all dates
#            rmse         mae      mape
# 0     17.338805   14.220011  0.008314
# 1     13.590564   11.199463  0.006510
# 2     23.981561   19.795247  0.011484
# 3     54.499429   44.713908  0.025355
# 4     76.244505   73.447428  0.041446
# ..          ...         ...       ...
# 584  106.650070  105.129232  0.038490
# 585  114.818381  114.285482  0.041901
# 586  128.406308  126.394206  0.046598
# 587  114.597340  112.484375  0.041783
# 588  114.882483  111.681559  0.041519
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    67.798624
# mae     62.901893
# mape     0.025924
# dtype: float64

# %% [markdown]
# ### Autoregressive

# %%
ar_grulstm_model, ar_grulstm_history, ar_grulstm_pred, ar_grulstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", grulstm, "Autoregressive")
# Out:
# Trial 10 Complete [00h 00m 31s]
# val_root_mean_squared_error: 0.10728925466537476
#
# Best val_root_mean_squared_error So Far: 0.09150080382823944
# Total elapsed time: 00h 08m 58s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Dataframe all dates
#            rmse         mae      mape
# 0     30.872122   23.618612  0.013985
# 1     34.671268   28.540975  0.016837
# 2     25.849297   21.496134  0.012601
# 3     20.530047   18.677856  0.010852
# 4     41.655699   41.356649  0.023822
# ..          ...         ...       ...
# 584   92.735081   92.060710  0.033876
# 585  103.687209  103.315348  0.038030
# 586  125.223858  123.544271  0.045598
# 587  121.013390  119.207357  0.044170
# 588  117.097510  113.366130  0.042108
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    70.321338
# mae     65.816849
# mape     0.027381
# dtype: float64

# %% [markdown]
# ## CNNLSTM

# %%
cnnlstm = cnn_lstm.BuildCNNLSTM

# %% [markdown]
# ### SingleShot

# %%
ss_cnnlstm_model, ss_cnnlstm_history, ss_cnnlstm_pred, ss_cnnlstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", cnnlstm, "SingleShot")
# Out:
# Trial 10 Complete [00h 00m 25s]
# val_root_mean_squared_error: 0.13269565999507904
#
# Best val_root_mean_squared_error So Far: 0.10242705047130585
# Total elapsed time: 00h 06m 15s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Dataframe all dates
#            rmse         mae      mape
# 0     19.350255   14.257365  0.008362
# 1     19.038306   16.878703  0.009851
# 2     23.408043   22.781291  0.013288
# 3     26.741741   24.592977  0.014262
# 4     38.407263   36.602783  0.021119
# ..          ...         ...       ...
# 584   86.702000   82.142822  0.030296
# 585   94.330026   93.200684  0.034427
# 586  122.035023  116.967448  0.043223
# 587  118.763976  116.378174  0.043159
# 588  111.438488  110.180094  0.041012
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    72.535918
# mae     67.479342
# mape     0.028332
# dtype: float64

# %% [markdown]
# ### Seq2Seq

# %%
seq2seq_cnnlstm_model, seq2seq_cnnlstm_history, seq2seq_cnnlstm_pred, seq2seq_cnnlstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", cnnlstm, "Seq2Seq")
# Out:
# Trial 10 Complete [00h 01m 03s]
# val_root_mean_squared_error: 0.10303368419408798
#
# Best val_root_mean_squared_error So Far: 0.10303368419408798
# Total elapsed time: 00h 07m 04s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Dataframe all dates
#            rmse         mae      mape
# 0     27.074775   21.889364  0.012920
# 1     28.523442   24.835449  0.014583
# 2     24.534254   22.420451  0.013122
# 3     21.421106   19.007690  0.011049
# 4     35.603107   34.682536  0.020047
# ..          ...         ...       ...
# 584   94.321489   92.753662  0.034114
# 585  106.613498  105.544596  0.038812
# 586  130.240060  128.549072  0.047359
# 587  130.708985  127.686117  0.047143
# 588  124.061484  121.910238  0.045167
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    73.970884
# mae     69.395419
# mape     0.029131
# dtype: float64

# %% [markdown]
# ### Autoregressive

# %%
ar_cnnlstm_model, ar_cnnlstm_history, ar_cnnlstm_pred, ar_cnnlstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", cnnlstm, "Autoregressive")
# Out:
# Trial 10 Complete [00h 00m 52s]
# val_root_mean_squared_error: 0.10942652821540833
#
# Best val_root_mean_squared_error So Far: 0.10636043548583984
# Total elapsed time: 00h 09m 17s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Dataframe all dates
#            rmse         mae      mape
# 0     22.228647   14.485799  0.008519
# 1     22.803870   18.834147  0.011018
# 2     23.042809   21.631185  0.012630
# 3     26.751852   25.530111  0.014816
# 4     37.431888   35.394816  0.020434
# ..          ...         ...       ...
# 584  110.121197  108.474365  0.039663
# 585  122.903255  122.512288  0.044784
# 586  149.503326  147.217367  0.053849
# 587  149.867083  148.234049  0.054341
# 588  143.149965  141.380452  0.052010
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    82.938994
# mae     78.875408
# mape     0.032733
# dtype: float64

# %% [markdown]
# ## BiLSTM

# %%
bi_lstm = bilstm.BuildBiLSTM

# %% [markdown]
# ### SingleShot

# %%
ss_bilstm_model, ss_bilstm_history, ss_bilstm_pred, ss_bilstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", bi_lstm, "SingleShot")
# Out:
# Trial 10 Complete [00h 01m 03s]
# val_root_mean_squared_error: 0.0954703614115715
#
# Best val_root_mean_squared_error So Far: 0.09044501930475235
# Total elapsed time: 00h 09m 11s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Dataframe all dates
#            rmse         mae      mape
# 0     43.611563   36.467285  0.021819
# 1     47.345117   43.190633  0.025692
# 2     37.960412   34.882528  0.020617
# 3     17.206917   15.067749  0.008806
# 4     28.316823   27.838420  0.016162
# ..          ...         ...       ...
# 584  100.904294   99.903727  0.036653
# 585  111.890908  111.627686  0.040968
# 586  133.258239  131.275635  0.048308
# 587  128.191690  126.599284  0.046785
# 588  125.594220  122.609863  0.045399
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    71.240204
# mae     66.692393
# mape     0.027626
# dtype: float64

# %% [markdown]
# ### Seq2Seq

# %%
seq2seq_bilstm_model, seq2seq_bilstm_history, seq2seq_bilstm_pred, seq2seq_bilstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", bi_lstm, "Seq2Seq")
# Out:
# Trial 10 Complete [00h 00m 51s]
# val_root_mean_squared_error: 0.09593959897756577
#
# Best val_root_mean_squared_error So Far: 0.08412860333919525
# Total elapsed time: 00h 15m 08s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# Dataframe all dates
#            rmse         mae      mape
# 0     22.469884   15.866659  0.009331
# 1     23.762776   19.715902  0.011541
# 2     21.833815   20.313232  0.011857
# 3     33.848695   29.211182  0.016814
# 4     56.531189   55.308431  0.031582
# ..          ...         ...       ...
# 584  101.972082   99.881917  0.036633
# 585  105.157590  104.562256  0.038474
# 586  126.416218  123.459066  0.045551
# 587  116.635111  114.291829  0.042424
# 588  108.273180  106.298421  0.039620
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    66.349009
# mae     61.452843
# mape     0.025448
# dtype: float64

# %% [markdown]
# ### Autoregressive

# %%
ar_bilstm_model, ar_bilstm_history, ar_bilstm_pred, ar_bilstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", bi_lstm, "Autoregressive")
# Out:
# Trial 10 Complete [00h 04m 18s]
# val_root_mean_squared_error: 0.09329227358102798
#
# Best val_root_mean_squared_error So Far: 0.08888186514377594
# Total elapsed time: 00h 21m 29s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# Dataframe all dates
#            rmse         mae      mape
# 0     35.547774   28.590088  0.017006
# 1     39.821720   35.509766  0.021021
# 2     32.448872   27.048991  0.015930
# 3     21.643452   19.635742  0.011420
# 4     36.559841   35.709391  0.020630
# ..          ...         ...       ...
# 584   87.826607   85.454346  0.031508
# 585   97.252637   96.889242  0.035754
# 586  119.795217  116.343506  0.043032
# 587  112.830854  111.009033  0.041264
# 588  109.017321  106.731283  0.039768
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    67.361064
# mae     62.595372
# mape     0.026072
# dtype: float64
