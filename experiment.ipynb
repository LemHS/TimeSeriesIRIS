# %%
from Model import bilstm, cnn_lstm, gru_lstm, vanilla_lstm
from train import train_model, evaluate_model, hypertune, plot_models

# %% [markdown]
# ## Vanilla LSTM

# %%
vilstm = vanilla_lstm.BuildVanillaLSTM

# %% [markdown]
# ### Single Shot

# %%
ss_vilstm_model, ss_vilstm_history, ss_vilstm_pred, ss_vilstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", vilstm, "SingleShot")
# Out:
# Trial 10 Complete [00h 00m 47s]
# val_root_mean_squared_error: 0.10850176960229874
#
# Best val_root_mean_squared_error So Far: 0.10711834579706192
# Total elapsed time: 00h 14m 04s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Dataframe all dates
#           rmse        mae      mape
# 0    76.369714  73.580160  0.044989
# 1    79.593415  78.103760  0.047412
# 2    75.178105  72.955851  0.044135
# 3    45.799869  40.338094  0.024183
# 4    19.330046  16.624064  0.009915
# ..         ...        ...       ...
# 584  30.923700  25.839437  0.009758
# 585  38.491021  34.880941  0.013163
# 586  62.204042  55.413818  0.020965
# 587  64.774822  58.457438  0.022142
# 588  61.355688  59.038167  0.022409
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    72.380100
# mae     67.241870
# mape     0.028874
# dtype: float64

# %% [markdown]
# ### Seq2Seq

# %%
seq2seq_vilstm_model, seq2seq_vilstm_history, seq2seq_vilstm_pred, seq2seq_vilstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", vilstm, "Seq2Seq")
# Out:
# Trial 10 Complete [00h 00m 47s]
# val_root_mean_squared_error: 0.08900512009859085
#
# Best val_root_mean_squared_error So Far: 0.08332855999469757
# Total elapsed time: 00h 17m 13s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Dataframe all dates
#           rmse        mae      mape
# 0    36.026421  31.634562  0.018837
# 1    48.083299  46.793660  0.027858
# 2    51.292347  46.866984  0.027943
# 3    25.999703  21.138468  0.012428
# 4    35.554530  31.888753  0.018421
# ..         ...        ...       ...
# 584  30.748752  24.208415  0.009137
# 585  33.624153  31.951823  0.012081
# 586  55.828097  50.360189  0.019105
# 587  43.625168  38.305908  0.014640
# 588  40.138366  29.878581  0.011438
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    57.839413
# mae     52.124997
# mape     0.022214
# dtype: float64

# %% [markdown]
# ### Autoregressive

# %%
ar_vilstm_model, ar_vilstm_history, ar_vilstm_pred, ar_vilstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", vilstm, "Autoregressive")
# Out:
# Trial 10 Complete [00h 01m 11s]
# val_root_mean_squared_error: 0.10748010873794556
#
# Best val_root_mean_squared_error So Far: 0.10422254353761673
# Total elapsed time: 00h 17m 53s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Dataframe all dates
#           rmse        mae      mape
# 0    71.455662  67.714518  0.041271
# 1    75.044350  73.103394  0.044249
# 2    69.567163  67.749471  0.040842
# 3    40.961620  36.054362  0.021544
# 4    14.243731  11.803914  0.007015
# ..         ...        ...       ...
# 584  25.748781  20.490560  0.007752
# 585  36.485295  35.165527  0.013280
# 586  60.406139  55.954753  0.021185
# 587  62.324368  58.191406  0.022063
# 588  62.752662  57.412516  0.021779
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    70.588298
# mae     65.605995
# mape     0.028140
# dtype: float64

# %% [markdown]
# ## GRULSTM

# %%
grulstm = gru_lstm.BuildGRULSTM

# %% [markdown]
# ### SingleShot

# %%
ss_grulstm_model, ss_grulstm_history, ss_grulstm_pred, ss_grulstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", grulstm, "SingleShot")
# Out:
# Trial 10 Complete [00h 00m 56s]
# val_root_mean_squared_error: 0.09854725748300552
#
# Best val_root_mean_squared_error So Far: 0.09816400706768036
# Total elapsed time: 00h 17m 16s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Dataframe all dates
#           rmse        mae      mape
# 0    74.145656  69.193319  0.042248
# 1    78.818641  75.852865  0.046024
# 2    71.272487  70.104818  0.042309
# 3    41.053166  38.263265  0.022868
# 4    12.641674  12.263102  0.007284
# ..         ...        ...       ...
# 584  26.170919  20.337891  0.007693
# 585  35.598102  33.711100  0.012736
# 586  58.980120  54.451742  0.020628
# 587  59.520665  54.331543  0.020624
# 588  56.620163  51.568929  0.019611
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    66.582001
# mae     61.475027
# mape     0.026372
# dtype: float64

# %% [markdown]
# ### Seq2Seq

# %%
seq2seq_grulstm_model, seq2seq_grulstm_history, seq2seq_grulstm_pred, seq2seq_grulstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", grulstm, "Seq2Seq")
# Out:
# Trial 10 Complete [00h 00m 34s]
# val_root_mean_squared_error: 0.07981941848993301
#
# Best val_root_mean_squared_error So Far: 0.07325755804777145
# Total elapsed time: 00h 32m 00s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Dataframe all dates
#           rmse        mae      mape
# 0    57.014069  52.801961  0.031881
# 1    49.347584  46.897095  0.027933
# 2    33.408517  28.809285  0.016978
# 3    32.026193  27.841675  0.016045
# 4    47.858534  46.595256  0.026740
# ..         ...        ...       ...
# 584  23.486884  18.416016  0.006976
# 585  28.911048  26.891276  0.010188
# 586  44.886296  37.417318  0.014264
# 587  26.391661  21.146810  0.008151
# 588  34.156575  25.336507  0.009729
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    52.130834
# mae     46.355075
# mape     0.019649
# dtype: float64

# %% [markdown]
# ### Autoregressive

# %%
ar_grulstm_model, ar_grulstm_history, ar_grulstm_pred, ar_grulstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", grulstm, "Autoregressive")
# Out:
# Trial 10 Complete [00h 01m 45s]
# val_root_mean_squared_error: 0.09318765252828598
#
# Best val_root_mean_squared_error So Far: 0.09054051339626312
# Total elapsed time: 00h 11m 25s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Dataframe all dates
#           rmse        mae      mape
# 0    65.341545  60.143758  0.036513
# 1    72.154085  69.272135  0.041856
# 2    64.052530  62.603312  0.037612
# 3    34.009334  29.975667  0.017827
# 4     4.735797   3.802409  0.002242
# ..         ...        ...       ...
# 584  25.389297  20.001221  0.007569
# 585  31.066948  28.744629  0.010881
# 586  55.176560  49.213786  0.018675
# 587  52.157349  46.050049  0.017536
# 588  46.035286  40.864014  0.015610
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    62.148084
# mae     56.964463
# mape     0.024376
# dtype: float64

# %% [markdown]
# ## CNNLSTM

# %%
cnnlstm = cnn_lstm.BuildCNNLSTM

# %% [markdown]
# ### SingleShot

# %%
ss_cnnlstm_model, ss_cnnlstm_history, ss_cnnlstm_pred, ss_cnnlstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", cnnlstm, "SingleShot")
# Out:
# Trial 10 Complete [00h 00m 37s]
# val_root_mean_squared_error: 0.12300931662321091
#
# Best val_root_mean_squared_error So Far: 0.1003374308347702
# Total elapsed time: 00h 11m 08s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Dataframe all dates
#           rmse        mae      mape
# 0    45.863550  36.747070  0.022026
# 1    48.605633  43.334798  0.025802
# 2    43.457913  41.756592  0.024770
# 3    21.943437  16.683390  0.009830
# 4     9.891044   9.303548  0.005462
# ..         ...        ...       ...
# 584  28.551187  22.481689  0.008500
# 585  30.411025  27.145833  0.010277
# 586  59.138206  51.023926  0.019329
# 587  58.392015  52.828044  0.020063
# 588  50.465294  47.279297  0.018026
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    67.705975
# mae     62.415081
# mape     0.026624
# dtype: float64

# %% [markdown]
# ### Seq2Seq

# %%
seq2seq_cnnlstm_model, seq2seq_cnnlstm_history, seq2seq_cnnlstm_pred, seq2seq_cnnlstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", cnnlstm, "Seq2Seq")
# Out:
# Trial 10 Complete [00h 00m 41s]
# val_root_mean_squared_error: 0.11055351048707962
#
# Best val_root_mean_squared_error So Far: 0.10138961672782898
# Total elapsed time: 00h 05m 24s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Dataframe all dates
#           rmse        mae      mape
# 0    69.150128  56.437866  0.034595
# 1    65.730127  61.404256  0.037202
# 2    69.689948  58.144653  0.035317
# 3    59.431648  46.716593  0.028281
# 4    41.844831  37.418498  0.022212
# ..         ...        ...       ...
# 584  41.081792  30.201497  0.011342
# 585  41.015354  35.658447  0.013430
# 586  71.475001  59.447428  0.022390
# 587  66.607002  60.376709  0.022840
# 588  55.927381  54.413086  0.020686
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    69.806684
# mae     63.510915
# mape     0.027169
# dtype: float64

# %% [markdown]
# ### Autoregressive

# %%
ar_cnnlstm_model, ar_cnnlstm_history, ar_cnnlstm_pred, ar_cnnlstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", cnnlstm, "Autoregressive")
# Out:
# Trial 10 Complete [00h 01m 13s]
# val_root_mean_squared_error: 0.10301637649536133
#
# Best val_root_mean_squared_error So Far: 0.10016673058271408
# Total elapsed time: 00h 13m 44s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# Dataframe all dates
#           rmse        mae      mape
# 0    62.172389  57.941081  0.035103
# 1    67.228053  64.391968  0.038788
# 2    65.782924  63.631470  0.038271
# 3    43.785936  39.684570  0.023759
# 4    10.875001   8.889689  0.005272
# ..         ...        ...       ...
# 584  22.204408  19.244466  0.007299
# 585  26.772962  23.153483  0.008780
# 586  52.831753  46.951009  0.017835
# 587  54.798242  48.309326  0.018375
# 588  47.747104  42.859212  0.016360
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    66.621599
# mae     61.460019
# mape     0.026217
# dtype: float64

# %% [markdown]
# ## BiLSTM

# %%
bi_lstm = bilstm.BuildBiLSTM

# %% [markdown]
# ### SingleShot

# %%
ss_bilstm_model, ss_bilstm_history, ss_bilstm_pred, ss_bilstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", bi_lstm, "SingleShot")
# Out:
# Trial 10 Complete [00h 01m 27s]
# val_root_mean_squared_error: 0.08404912799596786
#
# Best val_root_mean_squared_error So Far: 0.08265535533428192
# Total elapsed time: 00h 29m 16s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# Dataframe all dates
#           rmse        mae      mape
# 0    62.175996  58.104289  0.035201
# 1    66.692279  64.556396  0.038873
# 2    57.386441  54.963501  0.032885
# 3    26.630224  20.115601  0.011894
# 4    13.326210  11.216919  0.006574
# ..         ...        ...       ...
# 584  29.473159  21.597331  0.008156
# 585  34.017700  32.154867  0.012157
# 586  57.624999  50.850016  0.019276
# 587  49.250315  43.497477  0.016585
# 588  44.366884  39.160645  0.014970
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    57.207124
# mae     51.838484
# mape     0.022087
# dtype: float64

# %% [markdown]
# ### Seq2Seq

# %%
seq2seq_bilstm_model, seq2seq_bilstm_history, seq2seq_bilstm_pred, seq2seq_bilstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", bi_lstm, "Seq2Seq")
# Out:
# Trial 10 Complete [00h 02m 25s]
# val_root_mean_squared_error: 0.08133134245872498
#
# Best val_root_mean_squared_error So Far: 0.0760803371667862
# Total elapsed time: 00h 56m 56s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# Dataframe all dates
#           rmse        mae      mape
# 0    44.591567  38.767008  0.023212
# 1    51.884859  49.724976  0.029666
# 2    36.474313  32.510335  0.019197
# 3    25.377452  23.990845  0.013909
# 4    44.916877  43.816732  0.025190
# ..         ...        ...       ...
# 584  27.866840  20.750651  0.007843
# 585  30.709814  28.661784  0.010851
# 586  50.726671  43.420898  0.016509
# 587  35.267284  28.115885  0.010791
# 588  30.935081  23.065999  0.008872
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    52.980982
# mae     47.415377
# mape     0.020136
# dtype: float64

# %% [markdown]
# ### Autoregressive

# %%
ar_bilstm_model, ar_bilstm_history, ar_bilstm_pred, ar_bilstm_actual, test_date = hypertune("MYOR.JK", 0.1, 0.1, "2024-11-1", bi_lstm, "Autoregressive")
# Out:
# Trial 10 Complete [00h 12m 39s]
# val_root_mean_squared_error: 0.08776050806045532
#
# Best val_root_mean_squared_error So Far: 0.08485420048236847
# Total elapsed time: 00h 45m 55s
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# Dataframe all dates
#           rmse        mae      mape
# 0    63.076115  58.079183  0.035209
# 1    68.081571  64.694539  0.038992
# 2    57.740765  55.714925  0.033344
# 3    25.222618  19.490072  0.011516
# 4     9.283819   8.506429  0.004997
# ..         ...        ...       ...
# 584  30.082006  24.851318  0.009377
# 585  36.349379  36.139893  0.013645
# 586  61.538364  55.225667  0.020895
# 587  51.756219  49.012533  0.018662
# 588  52.215064  44.758545  0.017048
#
# [589 rows x 3 columns]
# Metrics mean
# rmse    58.691418
# mae     53.260085
# mape     0.022681
# dtype: float64
